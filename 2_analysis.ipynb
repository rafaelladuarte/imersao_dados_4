# %% [markdown]
# # Projeto de Precificação de Imóveis de São Paulo

# %% [markdown]
# ## Etapa 2: Análise Exploratória

# %% [markdown]
# Na segunda etapa do projeto, com os dataset criado e tratado da primeira etapa, iremos realizar uma análise explorátoria dos dados, de modo a:
#
# * Fazer um exame gráfico sobre a natureza das variáveis individuais;
# * Desenvolver uma análise descritiva para quantificar aspectos gráficos;
# * Identificar padrões e relacionais entre as variáveis levantadas;
# * Monitorar se há casos ausentes ou atípicos;
# * Levantar hipóteses básicas para testes estatísticos

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
from shapely.geometry import Point, Polygon

# %%
path = "https://raw.githubusercontent.com/rafaelladuarte/precificacao_imoveis/main/dados_aula_treatment.csv"

# %%
df = pd.read_csv(path)
df.sample(5)
# Out:
#       Unnamed: 0                             Rua            Bairro     Cidade  \
# 2538        2538                    Rua Curucáia             Saúde  São Paulo
# 1356        1356    Rua Constantino Fraga, , 26   Vila Hamburguesa  São Paulo
# 2849        2849               Rua Joazeiro, 66             Sumaré  São Paulo
# 4              4                 Rua Graham Bell       Santo Amaro  São Paulo
# 5510        5510  Rua José Joaquim Esteves, 645    Jardim São Luís  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas         Valor  Valor_anuncio  ...  \
# 2538       150        3          4      2    R$ 820.000       820000.0  ...
# 1356       145        2          2      3    R$ 980.000       980000.0  ...
# 2849       550        3          6      6  R$ 3.600.000      3600000.0  ...
# 4          440        4          4      6  R$ 1.980.000      1980000.0  ...
# 5510       115        3          2      3    R$ 650.000       650000.0  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5605 entries, 0 to 5604
# Data columns (total 52 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             5605 non-null   int64
#  1   Rua                    5605 non-null   object
#  2   Bairro                 5597 non-null   object
#  3   Cidade                 5605 non-null   object
#  4   Metragem               5605 non-null   int64
#  5   Quartos                5605 non-null   int64
#  6   Banheiros              5605 non-null   int64
#  7   Vagas                  5605 non-null   int64
#  8   Valor                  5605 non-null   object
#  9   Valor_anuncio          5605 non-null   float64
#  10  Tipo_anuncio           0 non-null      float64
#  11  Valor_mm               5605 non-null   float64
#  12  Valor_m2               5605 non-null   float64
#  13  rua                    5605 non-null   object
# ...

# %% [markdown]
# Começando com análise descritiva dos dados não geostacionários

# %%
df_1 = df.loc[:, ["Rua", "Bairro", "Metragem","Quartos","Banheiros","Vagas", "Valor_anuncio
